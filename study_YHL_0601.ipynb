# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns

# %%
#그래프 기본 스타일 지정
plt.style.use('seaborn')
sns.set(font_scale=2.5)

# %%
import missingno as msno
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

# %%
df_train = pd.read_csv('titanic/train.csv')
df_test = pd.read_csv('titanic/test.csv')

# %%
df_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
msno.matrix(df_test)

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
for col in df_train.columns:
    msg = 'columns : {:>10} Percent of NaN value : {:.2f}'.format(col, 100*(df_train[col].isnull().sum() / df_train[col].shape[0]))
    print(msg)
# Out:
# columns : PassengerId Percent of NaN value : 0.00
# columns :   Survived Percent of NaN value : 0.00
# columns :     Pclass Percent of NaN value : 0.00
# columns :       Name Percent of NaN value : 0.00
# columns :        Sex Percent of NaN value : 0.00
# columns :        Age Percent of NaN value : 19.87
# columns :      SibSp Percent of NaN value : 0.00
# columns :      Parch Percent of NaN value : 0.00
# columns :     Ticket Percent of NaN value : 0.00
# columns :       Fare Percent of NaN value : 0.00
# columns :      Cabin Percent of NaN value : 77.10
# columns :   Embarked Percent of NaN value : 0.22

# %%
for col in df_train.columns:
    msg = 'columns : {:<10}\t Percent of NaN value : {:.2f}'.format(col, 100*(df_train[col].isnull().sum() / df_train[col].shape[0]))
    print(msg)
# Out:
# columns : PassengerId	 Percent of NaN value : 0.00
# columns : Survived  	 Percent of NaN value : 0.00
# columns : Pclass    	 Percent of NaN value : 0.00
# columns : Name      	 Percent of NaN value : 0.00
# columns : Sex       	 Percent of NaN value : 0.00
# columns : Age       	 Percent of NaN value : 19.87
# columns : SibSp     	 Percent of NaN value : 0.00
# columns : Parch     	 Percent of NaN value : 0.00
# columns : Ticket    	 Percent of NaN value : 0.00
# columns : Fare      	 Percent of NaN value : 0.00
# columns : Cabin     	 Percent of NaN value : 77.10
# columns : Embarked  	 Percent of NaN value : 0.22

# %%
for col in df_test.columns:
    msg = 'columns : {:<10}\t Percent of NaN value : {:.2f}'.format(col, 100*(df_test[col].isnull().sum() / df_test[col].shape[0]))
    print(msg)
# Out:
# columns : PassengerId	 Percent of NaN value : 0.00
# columns : Pclass    	 Percent of NaN value : 0.00
# columns : Name      	 Percent of NaN value : 0.00
# columns : Sex       	 Percent of NaN value : 0.00
# columns : Age       	 Percent of NaN value : 20.57
# columns : SibSp     	 Percent of NaN value : 0.00
# columns : Parch     	 Percent of NaN value : 0.00
# columns : Ticket    	 Percent of NaN value : 0.00
# columns : Fare      	 Percent of NaN value : 0.24
# columns : Cabin     	 Percent of NaN value : 78.23
# columns : Embarked  	 Percent of NaN value : 0.00

# %%
msno.matrix(df_train, figsize=(8,8), color=(0.8, 0.5, 0.5))

# %%
msno.bar(df_train, figsize=(8,8), color=(0.5,0.5,0.1))

# %% [markdown]
# ## 그래프 그리기

# %%
f, ax = plt.subplots(1, 2, figsize=(15,8))

df_train['Survived'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Pie plot - Survived')
ax[0].set_ylabel('')
sns.countplot('Survived', data=df_train, ax=ax[1])
ax[1].set_title('Count plot - Survived')
plt.show()

# %%
df_train.shape
# Out:
# (891, 12)

# %% [markdown]
# ### 2.1 Pclass

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass']).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True)
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True).style.background_gradient(cmap='RdPu')
# Out:
# <style  type="text/css" >
#     #T_bc0c0570_8461_11e9_b6fb_acde48001122row0_col0 {
#             background-color:  #fff7f3;
#             color:  #000000;
#         }    #T_bc0c0570_8461_11e9_b6fb_acde48001122row0_col1 {
#             background-color:  #fcd1cd;
#             color:  #000000;
#         }    #T_bc0c0570_8461_11e9_b6fb_acde48001122row0_col2 {
#             background-color:  #feefeb;
#             color:  #000000;
#         }    #T_bc0c0570_8461_11e9_b6fb_acde48001122row1_col0 {
#             background-color:  #fef1ed;
#             color:  #000000;
#         }    #T_bc0c0570_8461_11e9_b6fb_acde48001122row1_col1 {
#             background-color:  #fff7f3;
#             color:  #000000;
#         }    #T_bc0c0570_8461_11e9_b6fb_acde48001122row1_col2 {
#             background-color:  #fff7f3;
#             color:  #000000;
#         }    #T_bc0c0570_8461_11e9_b6fb_acde48001122row2_col0 {
#             background-color:  #dd3597;
#             color:  #f1f1f1;
# ...

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass']).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar()

# %%
y_position = 1.02
f, ax = plt.subplots(1,2, figsize=(15,8))

df_train['Pclass'].value_counts().plot.bar(color=['#CD7F32', '#FFDF00', '#D3D3D3'], ax=ax[0])
ax[0].set_title('Number of passenfers By Pclass', y=y_position)
ax[0].set_ylabel('Count')
sns.countplot('Pclass', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Pclass: Survived vs dead', y=y_position)
plt.show()

# %% [markdown]
# > 함수를 이용한 그래프

# %%
def bar_chart(feature):
    survived = df_train[df_train['Survived']==1][feature].value_counts()
    dead = df_train[df_train['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived, dead])
    df.index = ('Survived', 'Dead')
    df.plot(kind='bar', stacked = True, figsize=(10,8))

# %%
bar_chart('Pclass')

# %%
bar_chart('Sex')

# %%
f, ax = plt.subplots(1,2, figsize=(15,8))
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue='Survived', data = df_train, ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
# Out:
# Text(0.5, 1.0, 'Sex:Survived vs Dead')

# %%
pd.crosstab(df_train['Sex'], df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_946a2758_8467_11e9_a79e_acde48001122row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_946a2758_8467_11e9_a79e_acde48001122row0_col1 {
#             background-color:  #77bb66;
#             color:  #000000;
#         }    #T_946a2758_8467_11e9_a79e_acde48001122row0_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_946a2758_8467_11e9_a79e_acde48001122row1_col0 {
#             background-color:  #2c9666;
#             color:  #000000;
#         }    #T_946a2758_8467_11e9_a79e_acde48001122row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_946a2758_8467_11e9_a79e_acde48001122row1_col2 {
#             background-color:  #8bc566;
#             color:  #000000;
#         }    #T_946a2758_8467_11e9_a79e_acde48001122row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
# ...

# %%
df_train.pivot_table(values='Survived', index='Sex', columns='Pclass', aggfunc='mean', margins=True)
# Out:
# Pclass         1         2         3       All
# Sex
# female  0.968085  0.921053  0.500000  0.742038
# male    0.368852  0.157407  0.135447  0.188908
# All     0.629630  0.472826  0.242363  0.383838

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=df_train, size=6, aspect=1.5)

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=df_train, size=6, aspect=1.5)

# %%
sns.factorplot(x='Sex', y='Survived', col='Pclass', data=df_train, saturation=5, size=6, aspect=1.3)

# %%
sns.factorplot(x='Sex', y='Survived', col='Pclass', data=df_train,size=6, aspect=1.3)

# %%
print("나이가 제일 많은 승객 : {:.1f} year".format(df_train['Age'].max()))
print("나이가 제일 적은 승객 : {:.1f} year".format(df_train['Age'].min()))
print("탑승객 평균나이 : {:.1f} year".format(df_train['Age'].mean()))
# Out:
# 나이가 제일 많은 승객 : 80.0 year
# 나이가 제일 적은 승객 : 0.4 year
# 탑승객 평균나이 : 29.7 year

# %%
foo = df_train['Age']

# %%
fig, ax = plt.subplots(1,1,figsize=(9,5))
sns.kdeplot(df_train[df_train['Survived'] ==1]['Age'], shade=True,ax=ax)
sns.kdeplot(df_train[df_train['Survived'] ==0]['Age'], shade=True,ax=ax)
plt.legend(['Survive ==1', 'Survived==0'])
plt.show()

# %%
df_train[df_train['Survived']==1]['Age'].hist()

# %%
plt.figure(figsize=(8,6))

df_train['Age'][df_train['Pclass']==1].plot(kind='kde')
df_train['Age'][df_train['Pclass']==2].plot(kind='kde')
df_train['Age'][df_train['Pclass']==3].plot(kind='kde')

plt.xlabel('Age')
plt.title('Age Distribution within classses')
plt.legend(['1st Class', '2nd Class', '3rd Class'])

# %%
f, ax = plt.subplots(1,1, figsize =(9,5))
sns.kdeplot(df_train[(df_train['Survived']==0)&(df_train['Pclass']==1)]['Age'], ax=ax)
sns.kdeplot(df_train[(df_train['Survived']==0)&(df_train['Pclass']==2)]['Age'], ax=ax)
sns.kdeplot(df_train[(df_train['Survived']==0)&(df_train['Pclass']==3)]['Age'], ax=ax)
plt.legend(['Pclass=1', 'Pclass=2', 'Pclass=3'])
plt.show()

# %%
f, ax = plt.subplots(1,1, figsize =(9,5))
sns.kdeplot(df_train[(df_train['Survived']==0)&(df_train['Pclass']==1)]['Age'], ax=ax)
sns.kdeplot(df_train[(df_train['Survived']==1)&(df_train['Pclass']==1)]['Age'], ax=ax)
plt.legend(['Survived==1', 'Survived==0'])
plt.title('1st Class')
plt.show()

# %%
f, ax = plt.subplots(1,1, figsize =(9,5))
sns.kdeplot(df_train[(df_train['Survived']==0)&(df_train['Pclass']==2)]['Age'], ax=ax)
sns.kdeplot(df_train[(df_train['Survived']==1)&(df_train['Pclass']==2)]['Age'], ax=ax)
plt.legend(['Survived==1', 'Survived==0'])
plt.title('2st Class')
plt.show()

# %%
f, ax = plt.subplots(1,1, figsize =(9,5))
sns.kdeplot(df_train[(df_train['Survived']==0)&(df_train['Pclass']==3)]['Age'], ax=ax)
sns.kdeplot(df_train[(df_train['Survived']==1)&(df_train['Pclass']==3)]['Age'], ax=ax)
plt.legend(['Survived==1', 'Survived==0'])
plt.title('3st Class')
plt.show()

# %% [markdown]
# ### #나이 어린 사람들이 정말 많이 살았는가?

# %%
change_age_range_survival_ratio = []

for i in range(0,80):
    change_age_range_survival_ratio.append(df_train[df_train['Age']<i]['Survived'].sum()/len(df_train[df_train['Age']<i]['Survived']))
plt.figure(figsize=(8,8))
plt.plot(change_age_range_survival_ratio)
plt.ylabel('Survived  rate')
plt.xlabel('Range of Age(0-X)')
plt.title('Survived rate change depending on range of Age')
# Out:
# Text(0.5, 1.0, 'Survived rate change depending on range of Age')
